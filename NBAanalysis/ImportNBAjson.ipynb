# %%
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
# Out:
# {'eventId': '1',
#  'home': {'abbreviation': 'GSW',
#   'name': 'Golden State Warriors',
#   'players': [{'firstname': 'Andrew',
#     'jersey': '12',
#     'lastname': 'Bogut',
#     'playerid': 101106,
#     'position': 'C'},
#    {'firstname': 'Festus',
#     'jersey': '31',
#     'lastname': 'Ezeli',
#     'playerid': 203105,
#     'position': 'C'},
#    {'firstname': 'James Michael',
#     'jersey': '20',
#     'lastname': 'McAdoo',
#     'playerid': 203949,
#     'position': 'F'},
#    {'firstname': 'Klay',
#     'jersey': '11',
#     'lastname': 'Thompson',
#     'playerid': 202691,
#     'position': 'G'},
#    {'firstname': 'Draymond',
#     'jersey': '23',
#     'lastname': 'Green',
#     'playerid': 203110,
#     'position': 'F'},
#    {'firstname': 'Jason',
#     'jersey': '1',
#     'lastname': 'Thompson',
#     'playerid': 201574,
#     'position': 'F-C'},
#    {'firstname': 'Brandon',
#     'jersey': '4',
#     'lastname': 'Rush',
#     'playerid': 201575,
# ...
